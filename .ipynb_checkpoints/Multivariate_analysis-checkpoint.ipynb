# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import datasets

# %%
iris = datasets.load_iris()

#Converting the data into a dataframe
iris = pd.DataFrame(data = np.c_[iris['data'], iris['target']], columns = iris['feature_names'] + ['species'])

#Replacing the values with class labels
iris.species = np.where(iris.species == 0.0, 'setosa', np.where(iris.species==1.0,'versicolor', 'virginica'))
iris
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#        species
# 0       setosa
# ...

# %%
#Print the mean for every column by species
iris.groupby(by = 'species').mean()
# Out:
#             sepal length (cm)  sepal width (cm)  petal length (cm)  \
# species
# setosa                  5.006             3.428              1.462
# versicolor              5.936             2.770              4.260
# virginica               6.588             2.974              5.552
#
#             petal width (cm)
# species
# setosa                 0.246
# versicolor             1.326
# virginica              2.026

# %%
#Plot the mean for each feature for each label class
iris.groupby(by = "species").mean().plot(kind ='bar')

plt.title('Class Vs Measurements')
plt.ylabel("Mean measurement(cm)")
plt.xticks(rotation = 0)
plt.grid(True)

#Use the bbox to anchor function to place legend outside the plot area
plt.legend(loc = "upper left", bbox_to_anchor =(1,1))
plt.show()
